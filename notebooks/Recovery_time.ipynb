# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("../data/twitter/2019-12-15_Philippines_earthquake.csv")
data.date = pd.to_datetime(data.date)
data.head()
# Out:
#              user                               location                date  \
# 0    quakeupdates  USA, Australia, Indonesia, NZ & Japan 2019-12-17 19:21:20
# 1   BrainstormBot                                  Italy 2019-12-17 19:17:15
# 2        EQAlerts                                    NaN 2019-12-17 18:50:27
# 3         nononui                                    NaN 2019-12-17 18:31:59
# 4  DrStubblefield                             Orcutt, CA 2019-12-17 18:29:58
#
#   coordinates                                            content
# 0         NaN  A M4.8 earthquake has been reported by the BMK...
# 1         NaN  ❗ LINOG PASIDAAN / LINDOL BABALA / EARTHQUAKE ...
# 2         NaN  #Earthquake M3.2 002 km S 34° W of Kiblawan (D...
# 3         NaN  Powerful earthquake of magnitude 6.8 strikes n...
# 4         NaN  Watch "12/15/2019 -- Large M6.9 (M6.8) earthqu...

# %%
plt.plot(data.date, data["content"].apply(lambda x: x.count("earthquake")));
